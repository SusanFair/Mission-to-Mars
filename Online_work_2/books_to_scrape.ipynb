# %%
# Import dependencies
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %%
# Set up Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# Visit the Quotes to Scrape the Site http://quotes.toscrape.com/
url = 'http://books.toscrape.com/'
browser.visit(url)

# Parse the HTML
html = browser.html
book_soup = soup(html, 'html.parser')

# %%
newtry = book_soup.find('ul', class_='nav-list')
newtry
# Out:
# <ul class="nav nav-list">
# <li>
# <a href="catalogue/category/books_1/index.html">
#
#                                 Books
#
#                         </a>
# <ul>
# <li>
# <a href="catalogue/category/books/travel_2/index.html">
#
#                                 Travel
#
#                         </a>
# </li>
# <li>
# <a href="catalogue/category/books/mystery_3/index.html">
#
#                                 Mystery
#
#                         </a>
# </li>
# <li>
# <a href="catalogue/category/books/historical-fiction_4/index.html">
#
#                                 Historical Fiction
#
#                         </a>
# </li>
# <li>
# <a href="catalogue/category/books/sequential-art_5/index.html">
#
#                                 Sequential Art
#
#                         </a>
# </li>
# <li>
# <a href="catalogue/category/books/classics_6/index.html">
#
#                                 Classics
#
#                         </a>
# </li>
# <li>
# ...

# %%
finaltry = newtry.get_text()
print(finaltry)
# Out:
#
#                                 Books
#
#
#
#
#
#
#                                 Travel
#
#
#
#
#
#
#                                 Mystery
#
#
#
#
#
#
#                                 Historical Fiction
#
#
#
#
#
#
#                                 Sequential Art
#
#
#
#
#
#
#                                 Classics
#
#
#
#
#
#
#                                 Philosophy
#
#
#
#
#
#
#                                 Romance
#
#
#
#
#
#
#                                 Womens Fiction
#
#
#
#
#
#
#                                 Fiction
#
#
#
#
#
#
#                                 Childrens
#
#
#
#
#
#
#                                 Religion
#
#
#
#
#
#
#                                 Nonfiction
#
#
#
#
#
#
#                                 Music
#
#
#
#
#
#
#                                 Default
#
#
#
#
#
#
#                                 Science Fiction
#
#
#
#
#
#
#                                 Sports and Games
#
#
#
#
#
#
# ...

# %%
newtry[0].li.a["href"]
# Out:
# 'index.html'

# %%
# visit 5 pages
booklist = []
newtry = book_soup.select('ul', class_='nav-list')

for x in range(0, 1):
    booklist = booklist.append(newtry[2].li.a["href"])
    
    print(booklist)
# Out:
# None

# %%
# visit 5 pages
for x in range(1, 6):
    newtry = book_soup.select('ul', class_='nav-list')
   
    print(newtry.li.a["href"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16332\3188012425.py in <module>
#       5     newtry = book_soup.select('ul', class_='nav-list')
#       6
# ----> 7     print(newtry.li.a["href"])
#
# ~\anaconda3\envs\PythonData\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2288         """Raise a helpful exception to explain a common code fix."""
#    2289         raise AttributeError(
# -> 2290             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291         )
#
# AttributeError: ResultSet object has no attribute 'li'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
for x in range(2, 20)
    newtry.li.a["href"]
    print x
# Out:
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16332\311912774.py", line 1
#     for x in range(2, 20)
#                          ^
# SyntaxError: invalid syntax

# %%
for x in newtry[1]:
    print(x.a[])
# Out:
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16332\3462184495.py", line 2
#     print(x.a[])
#               ^
# SyntaxError: invalid syntax

# %%
xleft = books[0].text.lstrip()
xright = xleft.rstrip()
print(xright)
# Out:
# Books
#
#
#
#
#
#
#                                 Travel
#
#
#
#
#
#
#                                 Mystery
#
#
#
#
#
#
#                                 Historical Fiction
#
#
#
#
#
#
#                                 Sequential Art
#
#
#
#
#
#
#                                 Classics
#
#
#
#
#
#
#                                 Philosophy
#
#
#
#
#
#
#                                 Romance
#
#
#
#
#
#
#                                 Womens Fiction
#
#
#
#
#
#
#                                 Fiction
#
#
#
#
#
#
#                                 Childrens
#
#
#
#
#
#
#                                 Religion
#
#
#
#
#
#
#                                 Nonfiction
#
#
#
#
#
#
#                                 Music
#
#
#
#
#
#
#                                 Default
#
#
#
#
#
#
#                                 Science Fiction
#
#
#
#
#
#
#                                 Sports and Games
#
#
#
#
#
#
#                                 Add a comment
#
#
#
#
#
#
# ...

# %%
/html/body/div/div/div/aside/div[2]/ul/li/ul

# %%
# Scrape all books on a single page
books = book_soup.find_all('ul', class_='nav-list')

for book in books:
    print(book.text)

removeSpace = book.replace('\n', ' ').replace('\r', '')
print(book.text)
# Out:
#
#                                 Books
#
#
#
#
#
#
#                                 Travel
#
#
#
#
#
#
#                                 Mystery
#
#
#
#
#
#
#                                 Historical Fiction
#
#
#
#
#
#
#                                 Sequential Art
#
#
#
#
#
#
#                                 Classics
#
#
#
#
#
#
#                                 Philosophy
#
#
#
#
#
#
#                                 Romance
#
#
#
#
#
#
#                                 Womens Fiction
#
#
#
#
#
#
#                                 Fiction
#
#
#
#
#
#
#                                 Childrens
#
#
#
#
#
#
#                                 Religion
#
#
#
#
#
#
#                                 Nonfiction
#
#
#
#
#
#
#                                 Music
#
#
#
#
#
#
#                                 Default
#
#
#
#
#
#
#                                 Science Fiction
#
#
#
#
#
#
#                                 Sports and Games
#
#
#
#
#
#
# ...

# %%
# Scrape all books on a single page
books = book_soup.find_all('ul', class_='nav-list')
books.li.a["href"]

#for x in newlist:
#    print(x.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16332\2876641777.py in <module>
#       1 # Scrape all books on a single page
#       2 books = book_soup.find_all('ul', class_='nav-list')
# ----> 3 books.li.a["href"]
#       4
#       5 #for x in newlist:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2288         """Raise a helpful exception to explain a common code fix."""
#    2289         raise AttributeError(
# -> 2290             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291         )
#
# ...

# %%
newtry.li.a["href"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16332\2924060420.py in <module>
# ----> 1 newtry.li.a["href"]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2288         """Raise a helpful exception to explain a common code fix."""
#    2289         raise AttributeError(
# -> 2290             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291         )
#
# AttributeError: ResultSet object has no attribute 'li'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
books = book_soup.find_all('ul', class_='nav-list')
print (books.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8324\389071483.py in <module>
#       1 books = book_soup.find_all('ul', class_='nav-list')
# ----> 2 print (books.text)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2288         """Raise a helpful exception to explain a common code fix."""
#    2289         raise AttributeError(
# -> 2290             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
# Scrape all books on a single page
books = book_soup.find_all('href', '" * "')

for book in books:
    print(book.text)

# %%
books = [book.text for book in book_soup.find_all("p", class_="availability instock")]

print(books)
# Out:
# []

# %%
books = [book.text for book in book_soup.find_all('ul', class_='nav-list')]

print(books)
# Out:
# ['\n\n\nBooks\n\n\n\n\n                            \n                                Travel\n                            \n                        \n\n\n\n                            \n                                Mystery\n                            \n                        \n\n\n\n                            \n                                Historical Fiction\n                            \n                        \n\n\n\n                            \n                                Sequential Art\n                            \n                        \n\n\n\n                            \n                                Classics\n                            \n                        \n\n\n\n                            \n                                Philosophy\n                            \n                        \n\n\n\n                            \n                                Romance\n                            \n                        \n\n\n\n                       
# ...

# %%
book_genres = [genre.text for genre in book_soup.find_all("li")]
print(book_genres)
# Out:
# ['\nHome\n', 'Books', '\n\nBooks\n\n\n\n\n                            \n                                Travel\n                            \n                        \n\n\n\n                            \n                                Mystery\n                            \n                        \n\n\n\n                            \n                                Historical Fiction\n                            \n                        \n\n\n\n                            \n                                Sequential Art\n                            \n                        \n\n\n\n                            \n                                Classics\n                            \n                        \n\n\n\n                            \n                                Philosophy\n                            \n                        \n\n\n\n                            \n                                Romance\n                            \n                        \n\n\n\n    
# ...

# %%
book_genres = [genre.text.strip(''#Text') for genre in book_soup.find_all("href=_")]
print(book_genres)
# Out:
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_8324\1400740149.py", line 2
#     print(book_genres)
#         ^
# SyntaxError: invalid syntax

# %%
# visit 5 pages
for x in range(1, 6):
    html = browser.html
    book_soup = soup(html, 'html.parser')
    books = books_soup.find_all('span', class_='text')
    
    for book in books:
        print('page:', x, '--------')
        print(books.text)
    browser.links.find_by_partial_text('Next').click()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8324\1471050775.py in <module>
#       3     html = browser.html
#       4     book_soup = soup(html, 'html.parser')
# ----> 5     books = books_soup.find_all('span', class_='text')
#       6
#       7     for book in books:
#
# NameError: name 'books_soup' is not defined

# %%
for x in range(1, 6):
    html = browser.html
    quote_soup = soup(html, 'html.parser')
    quotes = quote_soup.find_all('div', class_='quote')
    
    for quote in quotes:
        print('page:', x, '--------')
        print(quote.text)
    browser.links.find_by_partial_text('Next').click()
# Out:
# page: 1 --------
#
# “There is nothing I would not do for those who are really my friends. I have no notion of loving people by halves, it is not my nature.”
# by Jane Austen
# (about)
#
#
#             Tags:
#
# friendship
# love
#
#
# page: 1 --------
#
# “Do one thing every day that scares you.”
# by Eleanor Roosevelt
# (about)
#
#
#             Tags:
#
# attributed
# fear
# inspiration
#
#
# page: 1 --------
#
# “I am good, but not an angel. I do sin, but I am not the devil. I am just a small girl in a big world trying to find someone to love.”
# by Marilyn Monroe
# (about)
#
#
#             Tags:
#
# attributed-no-source
#
#
# page: 1 --------
#
# “If I were not a physicist, I would probably be a musician. I often think in music. I live my daydreams in music. I see my life in terms of music.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# music
#
#
# page: 1 --------
#
# ...

# %%
browser.quit()
